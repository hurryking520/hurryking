# %%
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import os

# %%
engine = create_engine('mysql+pymysql://root:root@localhost:3306/stock_db')

# %%
sql_stock_info = 'select * from stocks_dayk_all a where a.date >20181010 '
print(sql_stock_info)
df_stock_info = pd.read_sql_query(sql_stock_info,engine)
print('--------------------done--------------------------')
# Out:
# select * from stocks_dayk_all a where a.date >20181010
# --------------------done--------------------------

# %%
code_gb = df_stock_info.groupby('code')

# %%
file_data_normal = open('stock_data_normal','wb')
file_data = open('stock_data.csv','wb')
file_lable = open('stock_data_lable_normal.txt','wb')
file_data.truncate()
file_lable.truncate()
file_data_normal.truncate()
file_data.close()
file_lable.close()
file_data_normal.close()

# %%
def flag_train_data (code,duokong,index,date,df_dayk):
    i = 0
    index_count = len(date)
    list = []
    file = open('stock_data_lable_normal.txt','a+')
    data_count = 0
    lab_count = 0
    while(i < index_count -2 ):
        #print('-------- duokong ---------',duokong[i ],date[i])
        if duokong[i] == 2:   ##### 如果出现了  多
            
            #### 判断接下来 n 天，有没有出现 空
            start_index = index[i ] ##当前出现 多的 行号
            end_index = index[i +1] ##下一次出现空的行号
            #print('----间隔天数----',end_index - start_index +1)
            if end_index - start_index > 5 : #### 连续 6天 没有 空
                csv_df = df_dayk.loc[start_index:start_index+5,['open','close','high','low','rise','exchange','ma5','ma10','ma20','ma30','ma60']]
                #print(csv_df)
                '''
                csv_df['open'] = (csv_df['open'] - csv_df['open'].mean()) / csv_df['open'].std()
                csv_df['close'] = (csv_df['close'] - csv_df['close'].mean()) / csv_df['close'].std()
                csv_df['high'] = (csv_df['high'] - csv_df['high'].mean()) / csv_df['high'].std()
                csv_df['low'] = (csv_df['low'] - csv_df['low'].mean()) / csv_df['low'].std()
                csv_df['rise'] = (csv_df['rise'] - csv_df['rise'].mean()) / csv_df['rise'].std()
                csv_df['exchange'] = (csv_df['exchange'] - csv_df['exchange'].mean()) / csv_df['exchange'].std()
                csv_df['ma5'] = (csv_df['ma5'] - csv_df['ma5'].mean()) / csv_df['ma5'].std()
                csv_df['ma10'] = (csv_df['ma10'] - csv_df['ma10'].mean()) / csv_df['ma10'].std()
                csv_df['ma20'] = (csv_df['ma20'] - csv_df['ma20'].mean()) / csv_df['ma20'].std()
                csv_df['ma30'] = (csv_df['ma30'] - csv_df['ma30'].mean()) / csv_df['ma30'].std()
                csv_df['ma60'] = (csv_df['ma60'] - csv_df['ma60'].mean()) / csv_df['ma60'].std()
                '''
                csv_df['open'] = (csv_df['open'] - csv_df['open'].min()) / (csv_df['open'].max() - csv_df['open'].min())
                csv_df['close'] = (csv_df['close'] - csv_df['close'].min()) / (csv_df['close'].max() - csv_df['close'].min())
                csv_df['high'] = (csv_df['high'] - csv_df['high'].min()) / (csv_df['high'].max() - csv_df['high'].min())
                csv_df['low'] = (csv_df['low'] - csv_df['low'].min()) / (csv_df['low'].max() - csv_df['low'].min())
                csv_df['rise'] = (csv_df['rise'] - csv_df['rise'].min()) / (csv_df['rise'].max() - csv_df['rise'].min())
                csv_df['exchange'] = (csv_df['exchange'] - csv_df['exchange'].min()) / (csv_df['exchange'].max() - csv_df['exchange'].min())
                csv_df['ma5'] = (csv_df['ma5'] - csv_df['ma5'].min()) / (csv_df['ma5'].max() - csv_df['ma5'].min())
                csv_df['ma10'] = (csv_df['ma10'] - csv_df['ma10'].min()) / (csv_df['ma10'].max() - csv_df['ma10'].min())
                csv_df['ma20'] = (csv_df['ma20'] - csv_df['ma20'].min()) / (csv_df['ma20'].max() - csv_df['ma20'].min())
                csv_df['ma30'] = (csv_df['ma30'] - csv_df['ma30'].min()) / (csv_df['ma30'].max() - csv_df['ma30'].min())
                csv_df['ma60'] = (csv_df['ma60'] - csv_df['ma60'].min()) / (csv_df['ma60'].max() - csv_df['ma60'].min())           
                #print(csv_df)
                csv_df.to_csv('stock_data_normal.csv',mode = 'a',index=False,header=None,float_format='%.5f')
                #df_dayk.loc[start_index:start_index+5].to_csv('stock_data.csv',mode = 'a',index=False,header=None)
                data_count = data_count + 1
                if (df_dayk['open'][end_index+1] - df_dayk['open'][start_index+1]) / df_dayk['open'][start_index+1] > 0.1 :
                    #print('------满足条件------------')
                    file.write(code+','+date[i]+',1\n')
                else :
                    file.write(code+','+date[i]+',0\n')
                    #print('------不满足条件------------')
        i = i+1
        break
    file.close()

# %%
error = open('error.txt','a+')
for code,code_group in code_gb:
    
    print('code is ',code)
    df_stock_dayk = code_gb.get_group(code)
    df_stock_dayk = df_stock_dayk.sort_values(by='date',ascending=True)
    #print(df_stock_dayk.tail(10))
    #df_stock_dayk['index'] = np.arange(len(df_stock_dayk))
    df_duo = df_stock_dayk[(df_stock_dayk.duokong==2)|(df_stock_dayk.duokong==-1)]
    df_duo_index = df_duo.index.tolist()
    #print(df_duo)
    #print('-------------df_duo_index----------',df_duo_index)
    launch_date_sql = 'select * from stock_info where code=\''+code+'\' and launch_date < 20191010'
    print(launch_date_sql)
    df_launch_date = pd.read_sql_query(launch_date_sql,engine)
    print(df_launch_date.shape[0])
    if df_launch_date.shape[0] >0:
        flag_train_data(code,df_duo['duokong'].values,df_duo_index,df_duo['date'].values,df_stock_dayk)
    #print(train_index)
print('---------------done----------------------')
error.close()
# Out:
# code is  000001
# select * from stock_info where code='000001' and launch_date < 20191010
# 1
# code is  000002
# select * from stock_info where code='000002' and launch_date < 20191010
# 1
# code is  000004
# select * from stock_info where code='000004' and launch_date < 20191010
# 1
# code is  000005
# select * from stock_info where code='000005' and launch_date < 20191010
# 1
# code is  000006
# select * from stock_info where code='000006' and launch_date < 20191010
# 1
# code is  000007
# select * from stock_info where code='000007' and launch_date < 20191010
# 1
# code is  000008
# select * from stock_info where code='000008' and launch_date < 20191010
# 1
# code is  000009
# select * from stock_info where code='000009' and launch_date < 20191010
# 1
# code is  000010
# select * from stock_info where code='000010' and launch_date < 20191010
# 1
# code is  000011
# select * from stock_info where code='000011' and launch_date < 20191010
# 1
# code is  000012
# select * from stock_info where code='000012' and launch_date < 20191010
# 1
# code is  000014
# select * from stock_info where code='000014' and launch_date < 20191010
# 1
# code is  000016
# select * from stock_info where code='000016' and launch_date < 20191010
# 1
# code is  000017
# select * from stock_info where code='000017' and launch_date < 20191010
# 1
# code is  000019
# select * from stock_info where code='000019' and launch_date < 20191010
# 1
# code is  000020
# select * from stock_info where code='000020' and launch_date < 20191010
# 1
# code is  000021
# select * from stock_info where code='000021' and launch_date < 20191010
# 1
# code is  000023
# select * from stock_info where code='000023' and launch_date < 20191010
# 1
# code is  000025
# select * from stock_info where code='000025' and launch_date < 20191010
# 1
# code is  000026
# select * from stock_info where code='000026' and launch_date < 20191010
# 1
# code is  000027
# select * from stock_info where code='000027' and launch_date < 20191010
# 1
# code is  000028
# select * from stock_info where code='000028' and launch_date < 20191010
# 1
# code is  000030
# select * from stock_info where code='000030' and launch_date < 20191010
# 1
# code is  000031
# select * from stock_info where code='000031' and launch_date < 20191010
# 1
# code is  000032
# select * from stock_info where code='000032' and launch_date < 20191010
# 1
# code is  000034
# select * from stock_info where code='000034' and launch_date < 20191010
# 1
# code is  000035
# select * from stock_info where code='000035' and launch_date < 20191010
# 1
# code is  000036
# select * from stock_info where code='000036' and launch_date < 20191010
# 1
# code is  000037
# select * from stock_info where code='000037' and launch_date < 20191010
# 1
# code is  000038
# select * from stock_info where code='000038' and launch_date < 20191010
# 1
# code is  000039
# select * from stock_info where code='000039' and launch_date < 20191010
# 1
# code is  000040
# select * from stock_info where code='000040' and launch_date < 20191010
# 1
# code is  000042
# select * from stock_info where code='000042' and launch_date < 20191010
# 1
# code is  000045
# select * from stock_info where code='000045' and launch_date < 20191010
# 1
# code is  000046
# select * from stock_info where code='000046' and launch_date < 20191010
# 1
# code is  000048
# select * from stock_info where code='000048' and launch_date < 20191010
# 1
# code is  000049
# select * from stock_info where code='000049' and launch_date < 20191010
# 1
# code is  000050
# select * from stock_info where code='000050' and launch_date < 20191010
# 1
# code is  000055
# select * from stock_info where code='000055' and launch_date < 20191010
# 1
# code is  000056
# select * from stock_info where code='000056' and launch_date < 20191010
# 1
# code is  000058
# select * from stock_info where code='000058' and launch_date < 20191010
# 1
# code is  000059
# select * from stock_info where code='000059' and launch_date < 20191010
# 1
# code is  000060
# select * from stock_info where code='000060' and launch_date < 20191010
# 1
# code is  000061
# select * from stock_info where code='000061' and launch_date < 20191010
# 1
# code is  000062
# select * from stock_info where code='000062' and launch_date < 20191010
# 1
# code is  000063
# select * from stock_info where code='000063' and launch_date < 20191010
# 1
# code is  000065
# select * from stock_info where code='000065' and launch_date < 20191010
# 1
# code is  000066
# select * from stock_info where code='000066' and launch_date < 20191010
# 1
# code is  000068
# select * from stock_info where code='000068' and launch_date < 20191010
# 1
# code is  000069
# select * from stock_info where code='000069' and launch_date < 20191010
# 1
# code is  000070
# select * from stock_info where code='000070' and launch_date < 20191010
# 1
# code is  000078
# select * from stock_info where code='000078' and launch_date < 20191010
# 1
# code is  000088
# select * from stock_info where code='000088' and launch_date < 20191010
# 1
# code is  000089
# select * from stock_info where code='000089' and launch_date < 20191010
# 1
# code is  000090
# select * from stock_info where code='000090' and launch_date < 20191010
# 1
# code is  000096
# select * from stock_info where code='000096' and launch_date < 20191010
# 1
# code is  000099
# select * from stock_info where code='000099' and launch_date < 20191010
# 1
# code is  000100
# select * from stock_info where code='000100' and launch_date < 20191010
# 1
# code is  000150
# select * from stock_info where code='000150' and launch_date < 20191010
# 1
# code is  000151
# select * from stock_info where code='000151' and launch_date < 20191010
# 1
# code is  000153
# select * from stock_info where code='000153' and launch_date < 20191010
# 1
# code is  000155
# select * from stock_info where code='000155' and launch_date < 20191010
# 1
# code is  000156
# select * from stock_info where code='000156' and launch_date < 20191010
# 1
# code is  000157
# select * from stock_info where code='000157' and launch_date < 20191010
# 1
# code is  000158
# select * from stock_info where code='000158' and launch_date < 20191010
# 1
# code is  000159
# select * from stock_info where code='000159' and launch_date < 20191010
# 1
# code is  000166
# select * from stock_info where code='000166' and launch_date < 20191010
# 1
# code is  000301
# select * from stock_info where code='000301' and launch_date < 20191010
# 1
# code is  000333
# select * from stock_info where code='000333' and launch_date < 20191010
# 1
# code is  000338
# select * from stock_info where code='000338' and launch_date < 20191010
# 1
# code is  000400
# select * from stock_info where code='000400' and launch_date < 20191010
# 1
# code is  000401
# select * from stock_info where code='000401' and launch_date < 20191010
# 1
# code is  000402
# select * from stock_info where code='000402' and launch_date < 20191010
# 1
# code is  000403
# select * from stock_info where code='000403' and launch_date < 20191010
# 1
# code is  000404
# select * from stock_info where code='000404' and launch_date < 20191010
# 1
# code is  000407
# select * from stock_info where code='000407' and launch_date < 20191010
# 1
# code is  000408
# select * from stock_info where code='000408' and launch_date < 20191010
# 1
# code is  000409
# select * from stock_info where code='000409' and launch_date < 20191010
# 1
# code is  000410
# select * from stock_info where code='000410' and launch_date < 20191010
# 1
# code is  000411
# select * from stock_info where code='000411' and launch_date < 20191010
# 1
# code is  000413
# select * from stock_info where code='000413' and launch_date < 20191010
# 1
# code is  000415
# select * from stock_info where code='000415' and launch_date < 20191010
# 1
# code is  000416
# select * from stock_info where code='000416' and launch_date < 20191010
# 1
# code is  000417
# select * from stock_info where code='000417' and launch_date < 20191010
# 1
# code is  000419
# select * from stock_info where code='000419' and launch_date < 20191010
# 1
# code is  000420
# select * from stock_info where code='000420' and launch_date < 20191010
# 1
# code is  000421
# select * from stock_info where code='000421' and launch_date < 20191010
# 1
# code is  000422
# select * from stock_info where code='000422' and launch_date < 20191010
# 1
# code is  000423
# select * from stock_info where code='000423' and launch_date < 20191010
# 1
# code is  000425
# select * from stock_info where code='000425' and launch_date < 20191010
# 1
# code is  000426
# select * from stock_info where code='000426' and launch_date < 20191010
# 1
# code is  000428
# select * from stock_info where code='000428' and launch_date < 20191010
# 1
# code is  000429
# select * from stock_info where code='000429' and launch_date < 20191010
# 1
# code is  000430
# select * from stock_info where code='000430' and launch_date < 20191010
# 1
# code is  000488
# select * from stock_info where code='000488' and launch_date < 20191010
# 1
# code is  000498
# select * from stock_info where code='000498' and launch_date < 20191010
# 1
# code is  000501
# select * from stock_info where code='000501' and launch_date < 20191010
# 1
# code is  000502
# select * from stock_info where code='000502' and launch_date < 20191010
# 1
# code is  000503
# select * from stock_info where code='000503' and launch_date < 20191010
# 1
# code is  000504
# select * from stock_info where code='000504' and launch_date < 20191010
# 1
# code is  000505
# select * from stock_info where code='000505' and launch_date < 20191010
# 1
# code is  000506
# select * from stock_info where code='000506' and launch_date < 20191010
# 1
# code is  000507
# select * from stock_info where code='000507' and launch_date < 20191010
# 1
# code is  000509
# select * from stock_info where code='000509' and launch_date < 20191010
# 1
# code is  000510
# select * from stock_info where code='000510' and launch_date < 20191010
# 1
# code is  000513
# select * from stock_info where code='000513' and launch_date < 20191010
# 1
# code is  000514
# select * from stock_info where code='000514' and launch_date < 20191010
# 1
# code is  000516
# select * from stock_info where code='000516' and launch_date < 20191010
# 1
# code is  000517
# select * from stock_info where code='000517' and launch_date < 20191010
# 1
# code is  000518
# select * from stock_info where code='000518' and launch_date < 20191010
# 1
# code is  000519
# select * from stock_info where code='000519' and launch_date < 20191010
# 1
# code is  000520
# select * from stock_info where code='000520' and launch_date < 20191010
# 1
# code is  000521
# select * from stock_info where code='000521' and launch_date < 20191010
# 1
# code is  000523
# select * from stock_info where code='000523' and launch_date < 20191010
# 1
# code is  000524
# select * from stock_info where code='000524' and launch_date < 20191010
# 1
# code is  000525
# select * from stock_info where code='000525' and launch_date < 20191010
# 1
# code is  000526
# select * from stock_info where code='000526' and launch_date < 20191010
# 1
# code is  000528
# select * from stock_info where code='000528' and launch_date < 20191010
# 1
# code is  000529
# select * from stock_info where code='000529' and launch_date < 20191010
# 1
# code is  000530
# select * from stock_info where code='000530' and launch_date < 20191010
# 1
# code is  000531
# select * from stock_info where code='000531' and launch_date < 20191010
# 1
# code is  000532
# select * from stock_info where code='000532' and launch_date < 20191010
# 1
# code is  000533
# select * from stock_info where code='000533' and launch_date < 20191010
# 1
# code is  000534
# select * from stock_info where code='000534' and launch_date < 20191010
# 1
# code is  000536
# select * from stock_info where code='000536' and launch_date < 20191010
# 1
# code is  000537
# select * from stock_info where code='000537' and launch_date < 20191010
# 1
# code is  000538
# select * from stock_info where code='000538' and launch_date < 20191010
# 1
# code is  000539
# select * from stock_info where code='000539' and launch_date < 20191010
# 1
# code is  000540
# select * from stock_info where code='000540' and launch_date < 20191010
# 1
# code is  000541
# select * from stock_info where code='000541' and launch_date < 20191010
# 1
# code is  000543
# select * from stock_info where code='000543' and launch_date < 20191010
# 1
# code is  000544
# select * from stock_info where code='000544' and launch_date < 20191010
# 1
# code is  000545
# select * from stock_info where code='000545' and launch_date < 20191010
# 1
# code is  000546
# select * from stock_info where code='000546' and launch_date < 20191010
# 1
# code is  000547
# select * from stock_info where code='000547' and launch_date < 20191010
# 1
# code is  000548
# select * from stock_info where code='000548' and launch_date < 20191010
# 1
# code is  000550
# select * from stock_info where code='000550' and launch_date < 20191010
# 1
# code is  000551
# select * from stock_info where code='000551' and launch_date < 20191010
# 1
# code is  000552
# select * from stock_info where code='000552' and launch_date < 20191010
# 1
# code is  000553
# select * from stock_info where code='000553' and launch_date < 20191010
# 1
# code is  000554
# select * from stock_info where code='000554' and launch_date < 20191010
# 1
# code is  000555
# select * from stock_info where code='000555' and launch_date < 20191010
# 1
# code is  000557
# select * from stock_info where code='000557' and launch_date < 20191010
# 1
# code is  000558
# select * from stock_info where code='000558' and launch_date < 20191010
# 1
# code is  000559
# select * from stock_info where code='000559' and launch_date < 20191010
# 1
# code is  000560
# select * from stock_info where code='000560' and launch_date < 20191010
# 1
# code is  000561
# select * from stock_info where code='000561' and launch_date < 20191010
# 1
# code is  000563
# select * from stock_info where code='000563' and launch_date < 20191010
# 1
# code is  000564
# select * from stock_info where code='000564' and launch_date < 20191010
# 1
# code is  000565
# select * from stock_info where code='000565' and launch_date < 20191010
# 1
# code is  000566
# select * from stock_info where code='000566' and launch_date < 20191010
# 1
# code is  000567
# select * from stock_info where code='000567' and launch_date < 20191010
# 1
# code is  000568
# select * from stock_info where code='000568' and launch_date < 20191010
# 1
# code is  000570
# select * from stock_info where code='000570' and launch_date < 20191010
# 1
# code is  000571
# select * from stock_info where code='000571' and launch_date < 20191010
# 1
# code is  000572
# select * from stock_info where code='000572' and launch_date < 20191010
# 1
# code is  000573
# select * from stock_info where code='000573' and launch_date < 20191010
# 1
# code is  000576
# select * from stock_info where code='000576' and launch_date < 20191010
# 1
# code is  000581
# select * from stock_info where code='000581' and launch_date < 20191010
# 1
# code is  000582
# select * from stock_info where code='000582' and launch_date < 20191010
# 1
# code is  000584
# select * from stock_info where code='000584' and launch_date < 20191010
# 1
# code is  000585
# select * from stock_info where code='000585' and launch_date < 20191010
# 1
# code is  000586
# select * from stock_info where code='000586' and launch_date < 20191010
# 1
# code is  000587
# select * from stock_info where code='000587' and launch_date < 20191010
# 1
# code is  000589
# select * from stock_info where code='000589' and launch_date < 20191010
# 1
# code is  000590
# select * from stock_info where code='000590' and launch_date < 20191010
# 1
# code is  000591
# select * from stock_info where code='000591' and launch_date < 20191010
# 1
# code is  000592
# select * from stock_info where code='000592' and launch_date < 20191010
# 1
# code is  000593
# select * from stock_info where code='000593' and launch_date < 20191010
# 1
# code is  000595
# select * from stock_info where code='000595' and launch_date < 20191010
# 1
# code is  000596
# select * from stock_info where code='000596' and launch_date < 20191010
# 1
# code is  000597
# select * from stock_info where code='000597' and launch_date < 20191010
# 1
# code is  000598
# select * from stock_info where code='000598' and launch_date < 20191010
# 1
# code is  000599
# select * from stock_info where code='000599' and launch_date < 20191010
# 1
# code is  000600
# select * from stock_info where code='000600' and launch_date < 20191010
# 1
# code is  000601
# select * from stock_info where code='000601' and launch_date < 20191010
# 1
# code is  000603
# select * from stock_info where code='000603' and launch_date < 20191010
# 1
# code is  000605
# select * from stock_info where code='000605' and launch_date < 20191010
# 1
# code is  000606
# select * from stock_info where code='000606' and launch_date < 20191010
# 1
# code is  000607
# select * from stock_info where code='000607' and launch_date < 20191010
# 1
# code is  000608
# select * from stock_info where code='000608' and launch_date < 20191010
# 1
# code is  000609
# select * from stock_info where code='000609' and launch_date < 20191010
# 1
# code is  000610
# select * from stock_info where code='000610' and launch_date < 20191010
# 1
# code is  000611
# select * from stock_info where code='000611' and launch_date < 20191010
# 1
# code is  000612
# select * from stock_info where code='000612' and launch_date < 20191010
# 1
# code is  000613
# select * from stock_info where code='000613' and launch_date < 20191010
# 1
# code is  000615
# select * from stock_info where code='000615' and launch_date < 20191010
# 1
# code is  000616
# select * from stock_info where code='000616' and launch_date < 20191010
# 1
# code is  000617
# select * from stock_info where code='000617' and launch_date < 20191010
# 1
# code is  000619
# select * from stock_info where code='000619' and launch_date < 20191010
# 1
# code is  000620
# select * from stock_info where code='000620' and launch_date < 20191010
# 1
# code is  000622
# select * from stock_info where code='000622' and launch_date < 20191010
# 1
# code is  000623
# select * from stock_info where code='000623' and launch_date < 20191010
# 1
# code is  000625
# select * from stock_info where code='000625' and launch_date < 20191010
# 1
# code is  000626
# select * from stock_info where code='000626' and launch_date < 20191010
# 1
# code is  000627
# select * from stock_info where code='000627' and launch_date < 20191010
# 1
# code is  000628
# select * from stock_info where code='000628' and launch_date < 20191010
# 1
# code is  000629
# select * from stock_info where code='000629' and launch_date < 20191010
# 1
# code is  000630
# select * from stock_info where code='000630' and launch_date < 20191010
# 1
# code is  000631
# select * from stock_info where code='000631' and launch_date < 20191010
# 1
# code is  000632
# select * from stock_info where code='000632' and launch_date < 20191010
# 1
# code is  000633
# select * from stock_info where code='000633' and launch_date < 20191010
# 1
# code is  000635
# select * from stock_info where code='000635' and launch_date < 20191010
# 1
# code is  000636
# select * from stock_info where code='000636' and launch_date < 20191010
# 1
# code is  000637
# select * from stock_info where code='000637' and launch_date < 20191010
# 1
# code is  000638
# select * from stock_info where code='000638' and launch_date < 20191010
# 1
# code is  000639
# select * from stock_info where code='000639' and launch_date < 20191010
# 1
# code is  000650
# select * from stock_info where code='000650' and launch_date < 20191010
# 1
# code is  000651
# select * from stock_info where code='000651' and launch_date < 20191010
# 1
# code is  000652
# select * from stock_info where code='000652' and launch_date < 20191010
# 1
# code is  000655
# select * from stock_info where code='000655' and launch_date < 20191010
# 1
# code is  000656
# select * from stock_info where code='000656' and launch_date < 20191010
# 1
# code is  000657
# select * from stock_info where code='000657' and launch_date < 20191010
# 1
# code is  000659
# select * from stock_info where code='000659' and launch_date < 20191010
# 1
# code is  000661
# select * from stock_info where code='000661' and launch_date < 20191010
# 1
# code is  000662
# select * from stock_info where code='000662' and launch_date < 20191010
# 1
# code is  000663
# select * from stock_info where code='000663' and launch_date < 20191010
# 1
# code is  000665
# select * from stock_info where code='000665' and launch_date < 20191010
# 1
# code is  000666
# select * from stock_info where code='000666' and launch_date < 20191010
# 1
# code is  000667
# select * from stock_info where code='000667' and launch_date < 20191010
# 1
# code is  000668
# select * from stock_info where code='000668' and launch_date < 20191010
# 1
# code is  000669
# select * from stock_info where code='000669' and launch_date < 20191010
# 1
# code is  000670
# select * from stock_info where code='000670' and launch_date < 20191010
# 1
# code is  000671
# select * from stock_info where code='000671' and launch_date < 20191010
# 1
# code is  000672
# select * from stock_info where code='000672' and launch_date < 20191010
# 1
# code is  000673
# select * from stock_info where code='000673' and launch_date < 20191010
# 1
# code is  000676
# select * from stock_info where code='000676' and launch_date < 20191010
# 1
# code is  000677
# select * from stock_info where code='000677' and launch_date < 20191010
# 1
# code is  000678
# select * from stock_info where code='000678' and launch_date < 20191010
# 1
# code is  000679
# select * from stock_info where code='000679' and launch_date < 20191010
# 1
# code is  000680
# select * from stock_info where code='000680' and launch_date < 20191010
# 1
# code is  000681
# select * from stock_info where code='000681' and launch_date < 20191010
# 1
# code is  000682
# select * from stock_info where code='000682' and launch_date < 20191010
# 1
# code is  000683
# select * from stock_info where code='000683' and launch_date < 20191010
# 1
# code is  000685
# select * from stock_info where code='000685' and launch_date < 20191010
# 1
# code is  000686
# select * from stock_info where code='000686' and launch_date < 20191010
# 1
# code is  000687
# select * from stock_info where code='000687' and launch_date < 20191010
# 1
# code is  000688
# select * from stock_info where code='000688' and launch_date < 20191010
# 1
# code is  000690
# select * from stock_info where code='000690' and launch_date < 20191010
# 1
# code is  000691
# select * from stock_info where code='000691' and launch_date < 20191010
# 1
# code is  000692
# select * from stock_info where code='000692' and launch_date < 20191010
# 1
# code is  000695
# select * from stock_info where code='000695' and launch_date < 20191010
# 1
# code is  000697
# select * from stock_info where code='000697' and launch_date < 20191010
# 1
# code is  000698
# select * from stock_info where code='000698' and launch_date < 20191010
# 1
# code is  000700
# select * from stock_info where code='000700' and launch_date < 20191010
# 1
# code is  000701
# select * from stock_info where code='000701' and launch_date < 20191010
# 1
# code is  000702
# select * from stock_info where code='000702' and launch_date < 20191010
# 1
# code is  000703
# select * from stock_info where code='000703' and launch_date < 20191010
# 1
# code is  000705
# select * from stock_info where code='000705' and launch_date < 20191010
# 1
# code is  000707
# select * from stock_info where code='000707' and launch_date < 20191010
# 1
# code is  000708
# select * from stock_info where code='000708' and launch_date < 20191010
# 1
# code is  000709
# select * from stock_info where code='000709' and launch_date < 20191010
# 1
# code is  000710
# select * from stock_info where code='000710' and launch_date < 20191010
# 1
# code is  000711
# select * from stock_info where code='000711' and launch_date < 20191010
# 1
# code is  000712
# select * from stock_info where code='000712' and launch_date < 20191010
# 1
# code is  000713
# select * from stock_info where code='000713' and launch_date < 20191010
# 1
# code is  000715
# select * from stock_info where code='000715' and launch_date < 20191010
# 1
# code is  000716
# select * from stock_info where code='000716' and launch_date < 20191010
# 1
# code is  000717
# select * from stock_info where code='000717' and launch_date < 20191010
# 1
# code is  000718
# select * from stock_info where code='000718' and launch_date < 20191010
# 1
# code is  000719
# select * from stock_info where code='000719' and launch_date < 20191010
# 1
# code is  000720
# select * from stock_info where code='000720' and launch_date < 20191010
# 1
# code is  000721
# select * from stock_info where code='000721' and launch_date < 20191010
# 1
# code is  000722
# select * from stock_info where code='000722' and launch_date < 20191010
# 1
# code is  000723
# select * from stock_info where code='000723' and launch_date < 20191010
# 1
# code is  000725
# select * from stock_info where code='000725' and launch_date < 20191010
# 1
# code is  000726
# select * from stock_info where code='000726' and launch_date < 20191010
# 1
# code is  000727
# select * from stock_info where code='000727' and launch_date < 20191010
# 1
# code is  000728
# select * from stock_info where code='000728' and launch_date < 20191010
# 1
# code is  000729
# select * from stock_info where code='000729' and launch_date < 20191010
# 1
# code is  000731
# select * from stock_info where code='000731' and launch_date < 20191010
# 1
# code is  000732
# select * from stock_info where code='000732' and launch_date < 20191010
# 1
# code is  000733
# select * from stock_info where code='000733' and launch_date < 20191010
# 1
# code is  000735
# select * from stock_info where code='000735' and launch_date < 20191010
# 1
# code is  000736
# select * from stock_info where code='000736' and launch_date < 20191010
# 1
# code is  000737
# select * from stock_info where code='000737' and launch_date < 20191010
# 1
# code is  000738
# select * from stock_info where code='000738' and launch_date < 20191010
# 1
# code is  000739
# select * from stock_info where code='000739' and launch_date < 20191010
# 1
# code is  000750
# select * from stock_info where code='000750' and launch_date < 20191010
# 1
# code is  000751
# select * from stock_info where code='000751' and launch_date < 20191010
# 1
# code is  000752
# select * from stock_info where code='000752' and launch_date < 20191010
# 1
# code is  000753
# select * from stock_info where code='000753' and launch_date < 20191010
# 1
# code is  000755
# select * from stock_info where code='000755' and launch_date < 20191010
# 1
# code is  000756
# select * from stock_info where code='000756' and launch_date < 20191010
# 1
# code is  000757
# select * from stock_info where code='000757' and launch_date < 20191010
# 1
# code is  000758
# select * from stock_info where code='000758' and launch_date < 20191010
# 1
# code is  000759
# select * from stock_info where code='000759' and launch_date < 20191010
# 1
# code is  000760
# select * from stock_info where code='000760' and launch_date < 20191010
# 1
# code is  000761
# select * from stock_info where code='000761' and launch_date < 20191010
# 1
# code is  000762
# select * from stock_info where code='000762' and launch_date < 20191010
# 1
# code is  000766
# select * from stock_info where code='000766' and launch_date < 20191010
# 1
# code is  000767
# select * from stock_info where code='000767' and launch_date < 20191010
# 1
# code is  000768
# select * from stock_info where code='000768' and launch_date < 20191010
# 1
# code is  000776
# select * from stock_info where code='000776' and launch_date < 20191010
# 1
# code is  000777
# select * from stock_info where code='000777' and launch_date < 20191010
# 1
# code is  000778
# select * from stock_info where code='000778' and launch_date < 20191010
# 1
# code is  000779
# select * from stock_info where code='000779' and launch_date < 20191010
# 1
# code is  000780
# select * from stock_info where code='000780' and launch_date < 20191010
# 1
# code is  000782
# select * from stock_info where code='000782' and launch_date < 20191010
# 1
# code is  000783
# select * from stock_info where code='000783' and launch_date < 20191010
# 1
# code is  000785
# select * from stock_info where code='000785' and launch_date < 20191010
# 1
# code is  000786
# select * from stock_info where code='000786' and launch_date < 20191010
# 1
# code is  000788
# select * from stock_info where code='000788' and launch_date < 20191010
# 1
# code is  000789
# select * from stock_info where code='000789' and launch_date < 20191010
# 1
# code is  000790
# select * from stock_info where code='000790' and launch_date < 20191010
# 1
# code is  000791
# select * from stock_info where code='000791' and launch_date < 20191010
# 1
# code is  000792
# select * from stock_info where code='000792' and launch_date < 20191010
# 1
# code is  000793
# select * from stock_info where code='000793' and launch_date < 20191010
# 1
# code is  000795
# select * from stock_info where code='000795' and launch_date < 20191010
# 1
# code is  000796
# select * from stock_info where code='000796' and launch_date < 20191010
# 1
# code is  000797
# select * from stock_info where code='000797' and launch_date < 20191010
# 1
# code is  000798
# select * from stock_info where code='000798' and launch_date < 20191010
# 1
# code is  000799
# select * from stock_info where code='000799' and launch_date < 20191010
# 1
# code is  000800
# select * from stock_info where code='000800' and launch_date < 20191010
# 1
# code is  000801
# select * from stock_info where code='000801' and launch_date < 20191010
# 1
# code is  000802
# select * from stock_info where code='000802' and launch_date < 20191010
# 1
# code is  000803
# select * from stock_info where code='000803' and launch_date < 20191010
# 1
# code is  000806
# select * from stock_info where code='000806' and launch_date < 20191010
# 1
# code is  000807
# select * from stock_info where code='000807' and launch_date < 20191010
# 1
# code is  000809
# select * from stock_info where code='000809' and launch_date < 20191010
# 1
# code is  000810
# select * from stock_info where code='000810' and launch_date < 20191010
# 1
# code is  000811
# select * from stock_info where code='000811' and launch_date < 20191010
# 1
# code is  000812
# select * from stock_info where code='000812' and launch_date < 20191010
# 1
# code is  000813
# select * from stock_info where code='000813' and launch_date < 20191010
# 1
# code is  000815
# select * from stock_info where code='000815' and launch_date < 20191010
# 1
# code is  000816
# select * from stock_info where code='000816' and launch_date < 20191010
# 1
# code is  000818
# select * from stock_info where code='000818' and launch_date < 20191010
# 1
# code is  000819
# select * from stock_info where code='000819' and launch_date < 20191010
# 1
# code is  000820
# select * from stock_info where code='000820' and launch_date < 20191010
# 1
# code is  000821
# select * from stock_info where code='000821' and launch_date < 20191010
# 1
# code is  000822
# select * from stock_info where code='000822' and launch_date < 20191010
# 1
# code is  000823
# select * from stock_info where code='000823' and launch_date < 20191010
# 1
# code is  000825
# select * from stock_info where code='000825' and launch_date < 20191010
# 1
# code is  000826
# select * from stock_info where code='000826' and launch_date < 20191010
# 1
# code is  000828
# select * from stock_info where code='000828' and launch_date < 20191010
# 1
# code is  000829
# select * from stock_info where code='000829' and launch_date < 20191010
# 1
# code is  000830
# select * from stock_info where code='000830' and launch_date < 20191010
# 1
# code is  000831
# select * from stock_info where code='000831' and launch_date < 20191010
# 1
# code is  000833
# select * from stock_info where code='000833' and launch_date < 20191010
# 1
# code is  000835
# select * from stock_info where code='000835' and launch_date < 20191010
# 1
# code is  000836
# select * from stock_info where code='000836' and launch_date < 20191010
# 1
# code is  000837
# select * from stock_info where code='000837' and launch_date < 20191010
# 1
# code is  000838
# select * from stock_info where code='000838' and launch_date < 20191010
# 1
# code is  000839
# select * from stock_info where code='000839' and launch_date < 20191010
# 1
# code is  000848
# select * from stock_info where code='000848' and launch_date < 20191010
# 1
# code is  000850
# select * from stock_info where code='000850' and launch_date < 20191010
# 1
# code is  000851
# select * from stock_info where code='000851' and launch_date < 20191010
# 1
# code is  000852
# select * from stock_info where code='000852' and launch_date < 20191010
# 1
# code is  000856
# select * from stock_info where code='000856' and launch_date < 20191010
# 1
# code is  000858
# select * from stock_info where code='000858' and launch_date < 20191010
# 1
# code is  000859
# select * from stock_info where code='000859' and launch_date < 20191010
# 1
# code is  000860
# select * from stock_info where code='000860' and launch_date < 20191010
# 1
# code is  000861
# select * from stock_info where code='000861' and launch_date < 20191010
# 1
# code is  000862
# select * from stock_info where code='000862' and launch_date < 20191010
# 1
# code is  000863
# select * from stock_info where code='000863' and launch_date < 20191010
# 1
# code is  000868
# select * from stock_info where code='000868' and launch_date < 20191010
# 1
# code is  000869
# select * from stock_info where code='000869' and launch_date < 20191010
# 1
# code is  000875
# select * from stock_info where code='000875' and launch_date < 20191010
# 1
# code is  000876
# select * from stock_info where code='000876' and launch_date < 20191010
# 1
# code is  000877
# select * from stock_info where code='000877' and launch_date < 20191010
# 1
# code is  000878
# select * from stock_info where code='000878' and launch_date < 20191010
# 1
# code is  000880
# select * from stock_info where code='000880' and launch_date < 20191010
# 1
# code is  000881
# select * from stock_info where code='000881' and launch_date < 20191010
# 1
# code is  000882
# select * from stock_info where code='000882' and launch_date < 20191010
# 1
# code is  000883
# select * from stock_info where code='000883' and launch_date < 20191010
# 1
# code is  000885
# select * from stock_info where code='000885' and launch_date < 20191010
# 1
# code is  000886
# select * from stock_info where code='000886' and launch_date < 20191010
# 1
# code is  000887
# select * from stock_info where code='000887' and launch_date < 20191010
# 1
# code is  000888
# select * from stock_info where code='000888' and launch_date < 20191010
# 1
# code is  000889
# select * from stock_info where code='000889' and launch_date < 20191010
# 1
# code is  000890
# select * from stock_info where code='000890' and launch_date < 20191010
# 1
# code is  000892
# select * from stock_info where code='000892' and launch_date < 20191010
# 1
# code is  000893
# select * from stock_info where code='000893' and launch_date < 20191010
# 1
# code is  000895
# select * from stock_info where code='000895' and launch_date < 20191010
# 1
# code is  000897
# select * from stock_info where code='000897' and launch_date < 20191010
# 1
# code is  000898
# select * from stock_info where code='000898' and launch_date < 20191010
# 1
# code is  000899
# select * from stock_info where code='000899' and launch_date < 20191010
# 1
# code is  000900
# select * from stock_info where code='000900' and launch_date < 20191010
# 1
# code is  000901
# select * from stock_info where code='000901' and launch_date < 20191010
# 1
# code is  000902
# select * from stock_info where code='000902' and launch_date < 20191010
# 1
# code is  000903
# select * from stock_info where code='000903' and launch_date < 20191010
# 1
# code is  000905
# select * from stock_info where code='000905' and launch_date < 20191010
# 1
# code is  000906
# select * from stock_info where code='000906' and launch_date < 20191010
# 1
# code is  000908
# select * from stock_info where code='000908' and launch_date < 20191010
# 1
# code is  000909
# select * from stock_info where code='000909' and launch_date < 20191010
# 1
# code is  000910
# select * from stock_info where code='000910' and launch_date < 20191010
# 1
# code is  000911
# select * from stock_info where code='000911' and launch_date < 20191010
# 1
# code is  000912
# select * from stock_info where code='000912' and launch_date < 20191010
# 1
# code is  000913
# select * from stock_info where code='000913' and launch_date < 20191010
# 1
# code is  000915
# select * from stock_info where code='000915' and launch_date < 20191010
# 1
# code is  000917
# select * from stock_info where code='000917' and launch_date < 20191010
# 1
# code is  000918
# select * from stock_info where code='000918' and launch_date < 20191010
# 1
# code is  000919
# select * from stock_info where code='000919' and launch_date < 20191010
# 1
# code is  000920
# select * from stock_info where code='000920' and launch_date < 20191010
# 1
# code is  000921
# select * from stock_info where code='000921' and launch_date < 20191010
# 1
# code is  000922
# select * from stock_info where code='000922' and launch_date < 20191010
# 1
# code is  000923
# select * from stock_info where code='000923' and launch_date < 20191010
# 1
# code is  000925
# select * from stock_info where code='000925' and launch_date < 20191010
# 1
# code is  000926
# select * from stock_info where code='000926' and launch_date < 20191010
# 1
# code is  000927
# select * from stock_info where code='000927' and launch_date < 20191010
# 1
# code is  000928
# select * from stock_info where code='000928' and launch_date < 20191010
# 1
# code is  000929
# select * from stock_info where code='000929' and launch_date < 20191010
# 1
# code is  000930
# select * from stock_info where code='000930' and launch_date < 20191010
# 1
# code is  000931
# select * from stock_info where code='000931' and launch_date < 20191010
# 1
# code is  000932
# select * from stock_info where code='000932' and launch_date < 20191010
# 1
# code is  000933
# select * from stock_info where code='000933' and launch_date < 20191010
# 1
# code is  000935
# select * from stock_info where code='000935' and launch_date < 20191010
# 1
# code is  000936
# select * from stock_info where code='000936' and launch_date < 20191010
# 1
# code is  000937
# select * from stock_info where code='000937' and launch_date < 20191010
# 1
# code is  000938
# select * from stock_info where code='000938' and launch_date < 20191010
# 1
# code is  000939
# select * from stock_info where code='000939' and launch_date < 20191010
# 1
# code is  000948
# select * from stock_info where code='000948' and launch_date < 20191010
# 1
# code is  000949
# select * from stock_info where code='000949' and launch_date < 20191010
# 1
# code is  000950
# select * from stock_info where code='000950' and launch_date < 20191010
# 1
# code is  000951
# select * from stock_info where code='000951' and launch_date < 20191010
# 1
# code is  000952
# select * from stock_info where code='000952' and launch_date < 20191010
# 1
# code is  000953
# select * from stock_info where code='000953' and launch_date < 20191010
# 1
# code is  000955
# select * from stock_info where code='000955' and launch_date < 20191010
# 1
# code is  000957
# select * from stock_info where code='000957' and launch_date < 20191010
# 1
# code is  000958
# select * from stock_info where code='000958' and launch_date < 20191010
# 1
# code is  000959
# select * from stock_info where code='000959' and launch_date < 20191010
# 1
# code is  000960
# select * from stock_info where code='000960' and launch_date < 20191010
# 1
# code is  000961
# select * from stock_info where code='000961' and launch_date < 20191010
# 1
# code is  000962
# select * from stock_info where code='000962' and launch_date < 20191010
# 1
# code is  000963
# select * from stock_info where code='000963' and launch_date < 20191010
# 1
# code is  000965
# select * from stock_info where code='000965' and launch_date < 20191010
# 1
# code is  000966
# select * from stock_info where code='000966' and launch_date < 20191010
# 1
# code is  000967
# select * from stock_info where code='000967' and launch_date < 20191010
# 1
# code is  000968
# select * from stock_info where code='000968' and launch_date < 20191010
# 1
# code is  000969
# select * from stock_info where code='000969' and launch_date < 20191010
# 1
# code is  000970
# select * from stock_info where code='000970' and launch_date < 20191010
# 1
# code is  000971
# select * from stock_info where code='000971' and launch_date < 20191010
# 1
# code is  000972
# select * from stock_info where code='000972' and launch_date < 20191010
# 1
# code is  000973
# select * from stock_info where code='000973' and launch_date < 20191010
# 1
# code is  000975
# select * from stock_info where code='000975' and launch_date < 20191010
# 1
# code is  000976
# select * from stock_info where code='000976' and launch_date < 20191010
# 1
# code is  000977
# select * from stock_info where code='000977' and launch_date < 20191010
# 1
# code is  000978
# select * from stock_info where code='000978' and launch_date < 20191010
# 1
# code is  000980
# select * from stock_info where code='000980' and launch_date < 20191010
# 1
# code is  000981
# select * from stock_info where code='000981' and launch_date < 20191010
# 1
# code is  000982
# select * from stock_info where code='000982' and launch_date < 20191010
# 1
# code is  000983
# select * from stock_info where code='000983' and launch_date < 20191010
# 1
# code is  000985
# select * from stock_info where code='000985' and launch_date < 20191010
# 1
# code is  000987
# select * from stock_info where code='000987' and launch_date < 20191010
# 1
# code is  000988
# select * from stock_info where code='000988' and launch_date < 20191010
# 1
# code is  000989
# select * from stock_info where code='000989' and launch_date < 20191010
# 1
# code is  000990
# select * from stock_info where code='000990' and launch_date < 20191010
# 1
# code is  000993
# select * from stock_info where code='000993' and launch_date < 20191010
# 1
# code is  000995
# select * from stock_info where code='000995' and launch_date < 20191010
# 1
# code is  000996
# select * from stock_info where code='000996' and launch_date < 20191010
# 1
# code is  000997
# select * from stock_info where code='000997' and launch_date < 20191010
# 1
# code is  000998
# select * from stock_info where code='000998' and launch_date < 20191010
# 1
# code is  000999
# select * from stock_info where code='000999' and launch_date < 20191010
# 1
# code is  001696
# select * from stock_info where code='001696' and launch_date < 20191010
# 1
# code is  001872
# select * from stock_info where code='001872' and launch_date < 20191010
# 1
# code is  001896
# select * from stock_info where code='001896' and launch_date < 20191010
# 1
# code is  001914
# select * from stock_info where code='001914' and launch_date < 20191010
# 1
# code is  001965
# select * from stock_info where code='001965' and launch_date < 20191010
# 1
# code is  001979
# select * from stock_info where code='001979' and launch_date < 20191010
# 1
# code is  002001
# select * from stock_info where code='002001' and launch_date < 20191010
# 1
# code is  002002
# select * from stock_info where code='002002' and launch_date < 20191010
# 1
# code is  002003
# select * from stock_info where code='002003' and launch_date < 20191010
# 1
# code is  002004
# select * from stock_info where code='002004' and launch_date < 20191010
# 1
# code is  002005
# select * from stock_info where code='002005' and launch_date < 20191010
# 1
# code is  002006
# select * from stock_info where code='002006' and launch_date < 20191010
# 1
# code is  002007
# select * from stock_info where code='002007' and launch_date < 20191010
# 1
# code is  002008
# select * from stock_info where code='002008' and launch_date < 20191010
# 1
# code is  002009
# select * from stock_info where code='002009' and launch_date < 20191010
# 1
# code is  002010
# select * from stock_info where code='002010' and launch_date < 20191010
# 1
# code is  002011
# select * from stock_info where code='002011' and launch_date < 20191010
# 1
# code is  002012
# select * from stock_info where code='002012' and launch_date < 20191010
# 1
# code is  002013
# select * from stock_info where code='002013' and launch_date < 20191010
# 1
# code is  002014
# select * from stock_info where code='002014' and launch_date < 20191010
# 1
# code is  002015
# select * from stock_info where code='002015' and launch_date < 20191010
# 1
# code is  002016
# select * from stock_info where code='002016' and launch_date < 20191010
# 1
# code is  002017
# select * from stock_info where code='002017' and launch_date < 20191010
# 1
# code is  002019
# select * from stock_info where code='002019' and launch_date < 20191010
# 1
# code is  002020
# select * from stock_info where code='002020' and launch_date < 20191010
# 1
# code is  002021
# select * from stock_info where code='002021' and launch_date < 20191010
# 1
# code is  002022
# select * from stock_info where code='002022' and launch_date < 20191010
# 1
# code is  002023
# select * from stock_info where code='002023' and launch_date < 20191010
# 1
# code is  002024
# select * from stock_info where code='002024' and launch_date < 20191010
# 1
# code is  002025
# select * from stock_info where code='002025' and launch_date < 20191010
# 1
# code is  002026
# select * from stock_info where code='002026' and launch_date < 20191010
# 1
# code is  002027
# select * from stock_info where code='002027' and launch_date < 20191010
# 1
# code is  002028
# select * from stock_info where code='002028' and launch_date < 20191010
# 1
# code is  002029
# select * from stock_info where code='002029' and launch_date < 20191010
# 1
# code is  002030
# select * from stock_info where code='002030' and launch_date < 20191010
# 1
# code is  002031
# select * from stock_info where code='002031' and launch_date < 20191010
# 1
# code is  002032
# select * from stock_info where code='002032' and launch_date < 20191010
# 1
# code is  002033
# select * from stock_info where code='002033' and launch_date < 20191010
# 1
# code is  002034
# select * from stock_info where code='002034' and launch_date < 20191010
# 1
# code is  002035
# select * from stock_info where code='002035' and launch_date < 20191010
# 1
# code is  002036
# select * from stock_info where code='002036' and launch_date < 20191010
# 1
# code is  002037
# select * from stock_info where code='002037' and launch_date < 20191010
# 1
# code is  002038
# select * from stock_info where code='002038' and launch_date < 20191010
# 1
# code is  002039
# select * from stock_info where code='002039' and launch_date < 20191010
# 1
# code is  002040
# select * from stock_info where code='002040' and launch_date < 20191010
# 1
# code is  002041
# select * from stock_info where code='002041' and launch_date < 20191010
# 1
# code is  002042
# select * from stock_info where code='002042' and launch_date < 20191010
# 1
# code is  002043
# select * from stock_info where code='002043' and launch_date < 20191010
# 1
# code is  002044
# select * from stock_info where code='002044' and launch_date < 20191010
# 1
# code is  002045
# select * from stock_info where code='002045' and launch_date < 20191010
# 1
# code is  002046
# select * from stock_info where code='002046' and launch_date < 20191010
# 1
# code is  002047
# select * from stock_info where code='002047' and launch_date < 20191010
# 1
# code is  002048
# select * from stock_info where code='002048' and launch_date < 20191010
# 1
# code is  002049
# select * from stock_info where code='002049' and launch_date < 20191010
# 1
# code is  002050
# select * from stock_info where code='002050' and launch_date < 20191010
# 1
# code is  002051
# select * from stock_info where code='002051' and launch_date < 20191010
# 1
# code is  002052
# select * from stock_info where code='002052' and launch_date < 20191010
# 1
# code is  002053
# select * from stock_info where code='002053' and launch_date < 20191010
# 1
# code is  002054
# select * from stock_info where code='002054' and launch_date < 20191010
# 1
# code is  002055
# select * from stock_info where code='002055' and launch_date < 20191010
# 1
# code is  002056
# select * from stock_info where code='002056' and launch_date < 20191010
# 1
# code is  002057
# select * from stock_info where code='002057' and launch_date < 20191010
# 1
# code is  002058
# select * from stock_info where code='002058' and launch_date < 20191010
# 1
# code is  002059
# select * from stock_info where code='002059' and launch_date < 20191010
# 1
# code is  002060
# select * from stock_info where code='002060' and launch_date < 20191010
# 1
# code is  002061
# select * from stock_info where code='002061' and launch_date < 20191010
# 1
# code is  002062
# select * from stock_info where code='002062' and launch_date < 20191010
# 1
# code is  002063
# select * from stock_info where code='002063' and launch_date < 20191010
# 1
# code is  002064
# select * from stock_info where code='002064' and launch_date < 20191010
# 1
# code is  002065
# select * from stock_info where code='002065' and launch_date < 20191010
# 1
# code is  002066
# select * from stock_info where code='002066' and launch_date < 20191010
# 1
# code is  002067
# select * from stock_info where code='002067' and launch_date < 20191010
# 1
# code is  002068
# select * from stock_info where code='002068' and launch_date < 20191010
# 1
# code is  002069
# select * from stock_info where code='002069' and launch_date < 20191010
# 1
# code is  002071
# select * from stock_info where code='002071' and launch_date < 20191010
# 1
# code is  002072
# select * from stock_info where code='002072' and launch_date < 20191010
# 1
# code is  002073
# select * from stock_info where code='002073' and launch_date < 20191010
# 1
# code is  002074
# select * from stock_info where code='002074' and launch_date < 20191010
# 1
# code is  002075
# select * from stock_info where code='002075' and launch_date < 20191010
# 1
# code is  002076
# select * from stock_info where code='002076' and launch_date < 20191010
# 1
# code is  002077
# ...
# 1
# code is  603773
# select * from stock_info where code='603773' and launch_date < 20191010
# 1
# code is  603776
# select * from stock_info where code='603776' and launch_date < 20191010
# 1
# code is  603777
# select * from stock_info where code='603777' and launch_date < 20191010
# 1
# code is  603778
# select * from stock_info where code='603778' and launch_date < 20191010
# 1
# code is  603779
# select * from stock_info where code='603779' and launch_date < 20191010
# 1
# code is  603786
# select * from stock_info where code='603786' and launch_date < 20191010
# 0
# code is  603787
# select * from stock_info where code='603787' and launch_date < 20191010
# 1
# code is  603788
# select * from stock_info where code='603788' and launch_date < 20191010
# 1
# code is  603789
# select * from stock_info where code='603789' and launch_date < 20191010
# 1
# code is  603790
# select * from stock_info where code='603790' and launch_date < 20191010
# 1
# code is  603797
# select * from stock_info where code='603797' and launch_date < 20191010
# 1
# code is  603798
# select * from stock_info where code='603798' and launch_date < 20191010
# 1
# code is  603799
# select * from stock_info where code='603799' and launch_date < 20191010
# 1
# code is  603800
# select * from stock_info where code='603800' and launch_date < 20191010
# 1
# code is  603801
# select * from stock_info where code='603801' and launch_date < 20191010
# 1
# code is  603803
# select * from stock_info where code='603803' and launch_date < 20191010
# 1
# code is  603806
# select * from stock_info where code='603806' and launch_date < 20191010
# 1
# code is  603808
# select * from stock_info where code='603808' and launch_date < 20191010
# 1
# code is  603809
# select * from stock_info where code='603809' and launch_date < 20191010
# 1
# code is  603810
# select * from stock_info where code='603810' and launch_date < 20191010
# 1
# code is  603811
# select * from stock_info where code='603811' and launch_date < 20191010
# 1
# code is  603813
# select * from stock_info where code='603813' and launch_date < 20191010
# 1
# code is  603815
# select * from stock_info where code='603815' and launch_date < 20191010
# 0
# code is  603816
# select * from stock_info where code='603816' and launch_date < 20191010
# 1
# code is  603817
# select * from stock_info where code='603817' and launch_date < 20191010
# 1
# code is  603818
# select * from stock_info where code='603818' and launch_date < 20191010
# 1
# code is  603819
# select * from stock_info where code='603819' and launch_date < 20191010
# 1
# code is  603822
# select * from stock_info where code='603822' and launch_date < 20191010
# 1
# code is  603823
# select * from stock_info where code='603823' and launch_date < 20191010
# 1
# code is  603825
# select * from stock_info where code='603825' and launch_date < 20191010
# 1
# code is  603826
# select * from stock_info where code='603826' and launch_date < 20191010
# 1
# code is  603828
# select * from stock_info where code='603828' and launch_date < 20191010
# 1
# code is  603829
# select * from stock_info where code='603829' and launch_date < 20191010
# 1
# code is  603833
# select * from stock_info where code='603833' and launch_date < 20191010
# 1
# code is  603838
# select * from stock_info where code='603838' and launch_date < 20191010
# 1
# code is  603839
# select * from stock_info where code='603839' and launch_date < 20191010
# 1
# code is  603843
# select * from stock_info where code='603843' and launch_date < 20191010
# 1
# code is  603848
# select * from stock_info where code='603848' and launch_date < 20191010
# 1
# code is  603855
# select * from stock_info where code='603855' and launch_date < 20191010
# 1
# code is  603856
# select * from stock_info where code='603856' and launch_date < 20191010
# 1
# code is  603858
# select * from stock_info where code='603858' and launch_date < 20191010
# 1
# code is  603859
# select * from stock_info where code='603859' and launch_date < 20191010
# 1
# code is  603860
# select * from stock_info where code='603860' and launch_date < 20191010
# 1
# code is  603861
# select * from stock_info where code='603861' and launch_date < 20191010
# 1
# code is  603863
# select * from stock_info where code='603863' and launch_date < 20191010
# 1
# code is  603866
# select * from stock_info where code='603866' and launch_date < 20191010
# 1
# code is  603867
# select * from stock_info where code='603867' and launch_date < 20191010
# 1
# code is  603868
# select * from stock_info where code='603868' and launch_date < 20191010
# 1
# code is  603869
# select * from stock_info where code='603869' and launch_date < 20191010
# 1
# code is  603871
# select * from stock_info where code='603871' and launch_date < 20191010
# 1
# code is  603876
# select * from stock_info where code='603876' and launch_date < 20191010
# 1
# code is  603877
# select * from stock_info where code='603877' and launch_date < 20191010
# 1
# code is  603878
# select * from stock_info where code='603878' and launch_date < 20191010
# 1
# code is  603879
# select * from stock_info where code='603879' and launch_date < 20191010
# 1
# code is  603880
# select * from stock_info where code='603880' and launch_date < 20191010
# 1
# code is  603881
# select * from stock_info where code='603881' and launch_date < 20191010
# 1
# code is  603882
# select * from stock_info where code='603882' and launch_date < 20191010
# 1
# code is  603883
# select * from stock_info where code='603883' and launch_date < 20191010
# 1
# code is  603885
# select * from stock_info where code='603885' and launch_date < 20191010
# 1
# code is  603886
# select * from stock_info where code='603886' and launch_date < 20191010
# 1
# code is  603887
# select * from stock_info where code='603887' and launch_date < 20191010
# 1
# code is  603888
# select * from stock_info where code='603888' and launch_date < 20191010
# 1
# code is  603889
# select * from stock_info where code='603889' and launch_date < 20191010
# 1
# code is  603890
# select * from stock_info where code='603890' and launch_date < 20191010
# 1
# code is  603895
# select * from stock_info where code='603895' and launch_date < 20191010
# 1
# code is  603896
# select * from stock_info where code='603896' and launch_date < 20191010
# 1
# code is  603897
# select * from stock_info where code='603897' and launch_date < 20191010
# 1
# code is  603898
# select * from stock_info where code='603898' and launch_date < 20191010
# 1
# code is  603899
# select * from stock_info where code='603899' and launch_date < 20191010
# 1
# code is  603900
# select * from stock_info where code='603900' and launch_date < 20191010
# 1
# code is  603901
# select * from stock_info where code='603901' and launch_date < 20191010
# 1
# code is  603903
# select * from stock_info where code='603903' and launch_date < 20191010
# 1
# code is  603906
# select * from stock_info where code='603906' and launch_date < 20191010
# 1
# code is  603908
# select * from stock_info where code='603908' and launch_date < 20191010
# 1
# code is  603909
# select * from stock_info where code='603909' and launch_date < 20191010
# 1
# code is  603912
# select * from stock_info where code='603912' and launch_date < 20191010
# 1
# code is  603915
# select * from stock_info where code='603915' and launch_date < 20191010
# 1
# code is  603916
# select * from stock_info where code='603916' and launch_date < 20191010
# 1
# code is  603917
# select * from stock_info where code='603917' and launch_date < 20191010
# 1
# code is  603918
# select * from stock_info where code='603918' and launch_date < 20191010
# 1
# code is  603919
# select * from stock_info where code='603919' and launch_date < 20191010
# 1
# code is  603920
# select * from stock_info where code='603920' and launch_date < 20191010
# 1
# code is  603922
# select * from stock_info where code='603922' and launch_date < 20191010
# 1
# code is  603926
# select * from stock_info where code='603926' and launch_date < 20191010
# 1
# code is  603927
# select * from stock_info where code='603927' and launch_date < 20191010
# 1
# code is  603928
# select * from stock_info where code='603928' and launch_date < 20191010
# 1
# code is  603929
# select * from stock_info where code='603929' and launch_date < 20191010
# 1
# code is  603933
# select * from stock_info where code='603933' and launch_date < 20191010
# 1
# code is  603936
# select * from stock_info where code='603936' and launch_date < 20191010
# 1
# code is  603937
# select * from stock_info where code='603937' and launch_date < 20191010
# 1
# code is  603938
# select * from stock_info where code='603938' and launch_date < 20191010
# 1
# code is  603939
# select * from stock_info where code='603939' and launch_date < 20191010
# 1
# code is  603955
# select * from stock_info where code='603955' and launch_date < 20191010
# 1
# code is  603956
# select * from stock_info where code='603956' and launch_date < 20191010
# 1
# code is  603958
# select * from stock_info where code='603958' and launch_date < 20191010
# 1
# code is  603959
# select * from stock_info where code='603959' and launch_date < 20191010
# 1
# code is  603960
# select * from stock_info where code='603960' and launch_date < 20191010
# 1
# code is  603963
# select * from stock_info where code='603963' and launch_date < 20191010
# 1
# code is  603966
# select * from stock_info where code='603966' and launch_date < 20191010
# 1
# code is  603967
# select * from stock_info where code='603967' and launch_date < 20191010
# 1
# code is  603968
# select * from stock_info where code='603968' and launch_date < 20191010
# 1
# code is  603969
# select * from stock_info where code='603969' and launch_date < 20191010
# 1
# code is  603970
# select * from stock_info where code='603970' and launch_date < 20191010
# 1
# code is  603976
# select * from stock_info where code='603976' and launch_date < 20191010
# 1
# code is  603977
# select * from stock_info where code='603977' and launch_date < 20191010
# 1
# code is  603978
# select * from stock_info where code='603978' and launch_date < 20191010
# 1
# code is  603979
# select * from stock_info where code='603979' and launch_date < 20191010
# 1
# code is  603980
# select * from stock_info where code='603980' and launch_date < 20191010
# 1
# code is  603982
# select * from stock_info where code='603982' and launch_date < 20191010
# 1
# code is  603983
# select * from stock_info where code='603983' and launch_date < 20191010
# 1
# code is  603985
# select * from stock_info where code='603985' and launch_date < 20191010
# 1
# code is  603986
# select * from stock_info where code='603986' and launch_date < 20191010
# 1
# code is  603987
# select * from stock_info where code='603987' and launch_date < 20191010
# 1
# code is  603988
# select * from stock_info where code='603988' and launch_date < 20191010
# 1
# code is  603989
# select * from stock_info where code='603989' and launch_date < 20191010
# 1
# code is  603990
# select * from stock_info where code='603990' and launch_date < 20191010
# 1
# code is  603991
# select * from stock_info where code='603991' and launch_date < 20191010
# 1
# code is  603992
# select * from stock_info where code='603992' and launch_date < 20191010
# 1
# code is  603993
# select * from stock_info where code='603993' and launch_date < 20191010
# 1
# code is  603996
# select * from stock_info where code='603996' and launch_date < 20191010
# 1
# code is  603997
# select * from stock_info where code='603997' and launch_date < 20191010
# 1
# code is  603998
# select * from stock_info where code='603998' and launch_date < 20191010
# 1
# code is  603999
# select * from stock_info where code='603999' and launch_date < 20191010
# 1
# code is  688001
# select * from stock_info where code='688001' and launch_date < 20191010
# 1
# code is  688002
# select * from stock_info where code='688002' and launch_date < 20191010
# 1
# code is  688003
# select * from stock_info where code='688003' and launch_date < 20191010
# 1
# code is  688005
# select * from stock_info where code='688005' and launch_date < 20191010
# 1
# code is  688006
# select * from stock_info where code='688006' and launch_date < 20191010
# 1
# code is  688007
# select * from stock_info where code='688007' and launch_date < 20191010
# 1
# code is  688008
# select * from stock_info where code='688008' and launch_date < 20191010
# 1
# code is  688009
# select * from stock_info where code='688009' and launch_date < 20191010
# 1
# code is  688010
# select * from stock_info where code='688010' and launch_date < 20191010
# 1
# code is  688011
# select * from stock_info where code='688011' and launch_date < 20191010
# 1
# code is  688012
# select * from stock_info where code='688012' and launch_date < 20191010
# 1
# code is  688015
# select * from stock_info where code='688015' and launch_date < 20191010
# 1
# code is  688016
# select * from stock_info where code='688016' and launch_date < 20191010
# 1
# code is  688018
# select * from stock_info where code='688018' and launch_date < 20191010
# 1
# code is  688019
# select * from stock_info where code='688019' and launch_date < 20191010
# 1
# code is  688020
# select * from stock_info where code='688020' and launch_date < 20191010
# 1
# code is  688021
# select * from stock_info where code='688021' and launch_date < 20191010
# 0
# code is  688022
# select * from stock_info where code='688022' and launch_date < 20191010
# 1
# code is  688023
# select * from stock_info where code='688023' and launch_date < 20191010
# 0
# code is  688025
# select * from stock_info where code='688025' and launch_date < 20191010
# 0
# code is  688028
# select * from stock_info where code='688028' and launch_date < 20191010
# 1
# code is  688029
# select * from stock_info where code='688029' and launch_date < 20191010
# 1
# code is  688030
# select * from stock_info where code='688030' and launch_date < 20191010
# 1
# code is  688033
# select * from stock_info where code='688033' and launch_date < 20191010
# 1
# code is  688036
# select * from stock_info where code='688036' and launch_date < 20191010
# 1
# code is  688058
# select * from stock_info where code='688058' and launch_date < 20191010
# 0
# code is  688066
# select * from stock_info where code='688066' and launch_date < 20191010
# 1
# code is  688068
# select * from stock_info where code='688068' and launch_date < 20191010
# 1
# code is  688088
# select * from stock_info where code='688088' and launch_date < 20191010
# 1
# code is  688098
# select * from stock_info where code='688098' and launch_date < 20191010
# 0
# code is  688099
# select * from stock_info where code='688099' and launch_date < 20191010
# 1
# code is  688101
# select * from stock_info where code='688101' and launch_date < 20191010
# 0
# code is  688108
# select * from stock_info where code='688108' and launch_date < 20191010
# 0
# code is  688111
# select * from stock_info where code='688111' and launch_date < 20191010
# 0
# code is  688116
# select * from stock_info where code='688116' and launch_date < 20191010
# 1
# code is  688122
# select * from stock_info where code='688122' and launch_date < 20191010
# 1
# code is  688128
# select * from stock_info where code='688128' and launch_date < 20191010
# 0
# code is  688139
# select * from stock_info where code='688139' and launch_date < 20191010
# 0
# code is  688166
# select * from stock_info where code='688166' and launch_date < 20191010
# 0
# code is  688168
# select * from stock_info where code='688168' and launch_date < 20191010
# 1
# code is  688188
# select * from stock_info where code='688188' and launch_date < 20191010
# 1
# code is  688199
# select * from stock_info where code='688199' and launch_date < 20191010
# 0
# code is  688202
# select * from stock_info where code='688202' and launch_date < 20191010
# 0
# code is  688288
# select * from stock_info where code='688288' and launch_date < 20191010
# 0
# code is  688299
# select * from stock_info where code='688299' and launch_date < 20191010
# 0
# code is  688300
# select * from stock_info where code='688300' and launch_date < 20191010
# 0
# code is  688321
# select * from stock_info where code='688321' and launch_date < 20191010
# 1
# code is  688333
# select * from stock_info where code='688333' and launch_date < 20191010
# 1
# code is  688363
# select * from stock_info where code='688363' and launch_date < 20191010
# 0
# code is  688366
# select * from stock_info where code='688366' and launch_date < 20191010
# 0
# code is  688368
# select * from stock_info where code='688368' and launch_date < 20191010
# 0
# code is  688369
# select * from stock_info where code='688369' and launch_date < 20191010
# 0
# code is  688388
# select * from stock_info where code='688388' and launch_date < 20191010
# 1
# code is  688389
# select * from stock_info where code='688389' and launch_date < 20191010
# 0
# ---------------done----------------------
