# %%
from sqlalchemy import create_engine
import numpy as np
import pandas as pd

# %%
engine = create_engine('mysql+pymysql://root:root@localhost:3306/stock_db')

# %%
sql_test = 'select * from stock_ma where code<=002300'
print(sql_test)
df_read=pd.read_sql_query(sql_test,engine)
print('-----------------done-------------------')
# Out:
# select * from stock_ma where code<=002300
# -----------------done-------------------

# %%
def cross_np(var1,var2):
    np_duo_kong = np.zeros(len(var1))
    for i in range(1,len(var1)):
        if var1[i-1]<var2[i-1] and var1[i] > var2[i] :
            np_duo_kong[i]=1
        elif var1[i-1]>var2[i-1] and var1[i]<var2[i] :
            np_duo_kong[i]=-1
        else:
            np_duo_kong[i]=0
    return np_duo_kong

# %%
code_gb = df_read.groupby('code')

# %%
for code_name,code_group in code_gb:
    stock_dayk = code_gb.get_group(code_name) #### 获取单个股票的日线
    days_count = stock_dayk.shape[0]
    stock_duo_kong = pd.DataFrame({'duokong':np.arange(days_count)})
    if days_count>34 :
        stock_dayk = stock_dayk.sort_values(by='date',ascending=True)
        #print(stock_dayk)
        max_in_21 = stock_dayk['high'].rolling(21).max()
        low_in_21 = stock_dayk['low'].rolling(21).min()
        max_in_6 = stock_dayk['high'].rolling(6).max()
        low_in_6 = stock_dayk['low'].rolling(6).min()
        var1 = 100 - 90*(max_in_21 - stock_dayk['close'])/(max_in_21 - low_in_21)
        var2 = 100 - (100*(max_in_6 - stock_dayk['close'])/(max_in_6 - low_in_6)).rolling(34).mean()
        var3 = var2.rolling(6).mean()
        stock_duo_kong['duokong'] = pd.DataFrame(cross_np(var1.values,var3.values))
        stock_duo_kong['code'] = pd.DataFrame(stock_dayk['code'].values)
        stock_duo_kong['date'] = pd.DataFrame(stock_dayk['date'].values)
        stock_duo_kong['open'] = pd.DataFrame(stock_dayk['open'].values)
        stock_duo_kong['close'] = pd.DataFrame(stock_dayk['close'].values)
        stock_duo_kong.to_sql('stock_duo_kong',engine,index=False,if_exists='append')
    print('-------------------',code_name,' done ----------------------')

    
print('-----------------------------all done -----------------------')
# Out:
# ------------------- 000001  done ----------------------
# ------------------- 000002  done ----------------------
# ------------------- 000004  done ----------------------
# ------------------- 000005  done ----------------------
# ------------------- 000006  done ----------------------
# ------------------- 000007  done ----------------------
# ------------------- 000008  done ----------------------
# ------------------- 000009  done ----------------------
# ------------------- 000010  done ----------------------
# ------------------- 000011  done ----------------------
# ------------------- 000012  done ----------------------
# ------------------- 000014  done ----------------------
# ------------------- 000016  done ----------------------
# ------------------- 000017  done ----------------------
# ------------------- 000019  done ----------------------
# ------------------- 000020  done ----------------------
# ------------------- 000021  done ----------------------
# ...
